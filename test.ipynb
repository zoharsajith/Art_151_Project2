# %%
from bs4 import BeautifulSoup
import requests
import re

# %%
page = requests.get("https://kingsroadmerch.com/cannibal-corpse/")
soup = BeautifulSoup(page.content, "html.parser")
print(soup.title)
# Out:
# <title>Shop the Cannibal Corpse Online Store | Official Merch &amp; Music</title>

# %%
gallery = "gallery&400"
nerves = "nerves"
skeleton = "skeleton"
muscles = "muscles"

headers = {'User-Agent': 'Mozilla/5.0'}

number = 0

# %%
search = nerves
article = []
results = 100 # valid options 10, 20, 30, 40, 50, and 100
page = requests.get(f"https://www.google.com/search?q={search}&num={results}&pws=0",headers = headers)
soup = BeautifulSoup(page.content, "html.parser")
links = soup.findAll("a")
for link in links :
    link_href = link.get('href')
    if "url?q=" in link_href and not "webcache" in link_href:
        article.append((link.get('href').split("?q=")[1].split("&sa=U")[0]))

page = requests.get(f'{article[number]}', headers = headers)
soup = BeautifulSoup(page.text, 'html.parser')
text = soup.find('p').getText()
print(text)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-8-e65ee806b088> in <module>
#      10         article.append((link.get('href').split("?q=")[1].split("&sa=U")[0]))
#      11
# ---> 12 page = requests.get(f'{article[number]}', headers = headers)
#      13 soup = BeautifulSoup(page.text, 'html.parser')
#      14 text = soup.find('p').getText()
#
# IndexError: list index out of range

# %%
for i in range(0, 20):
        if i < 20:
            #move through list
            search = nerves
            article = []
            results = 100 # valid options 10, 20, 30, 40, 50, and 100
            page = requests.get(f"https://www.bing.com/search?q={search}&num={results}&pws=0",headers = headers)
            soup = BeautifulSoup(page.content, "html.parser")
            links = soup.findAll("a")
            for link in range(0, links.count(link) -1):
                link_href = link.get('href')
                print(link_href)
                if "None" in link_href:
                    break
                
                if "url?q=" in link_href and not "webcache" in link_href:
                    article.append((link.get('href').split("?q=")[1].split("&sa=U")[0]))
                

            page = requests.get(f'{article[number]}', headers = headers)
            soup = BeautifulSoup(page.text, 'html.parser')
            text = soup.find('p').getText()
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-12-4dba0e3d0786> in <module>
#      18
#      19
# ---> 20             page = requests.get(f'{article[number]}', headers = headers)
#      21             soup = BeautifulSoup(page.text, 'html.parser')
#      22             text = soup.find('p').getText()
#
# IndexError: list index out of range
